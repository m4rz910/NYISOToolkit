# %%
import pytest
from datetime import datetime
import pytz
import matplotlib.pyplot as plt

from nyisotoolkit import NYISOVis
from nyisotoolkit.nyisovis.nyisovis import basic_plots, statistical_plots
from nyisotoolkit.nyisodata.utils import current_year

basic_plots({"redownload":True, 'year': 2021})
# Out:
# Downloading 2021 fuel_mix_5m...Completed!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4768/4045843921.py in <module>
#       8 from nyisotoolkit.nyisodata.utils import current_year
#       9
# ---> 10 basic_plots({"redownload":True, 'year': 2021})
#
# c:\users\tzave\synologydrive\drive\zachary\160-energy\personal_projects\nyisotoolkit\nyisotoolkit\nyisovis\nyisovis.py in basic_plots(nyisovis_kwa)
#     538
#     539 def basic_plots(nyisovis_kwa):
# --> 540     nv = NYISOVis(**nyisovis_kwa)
#     541     nv.fig_carbon_free_year()
#     542     nv.fig_decarbonization_heatmap()
#
# c:\users\tzave\synologydrive\drive\zachary\160-energy\personal_projects\nyisotoolkit\nyisotoolkit\nyisovis\nyisovis.py in __init__(self, year, out_dir, **kwargs)
#      67             existing_datasets = [db.name.replace(".pkl","").replace(f"{self.year}_","") for db in existing_dbs]
#      68             for dataset in existing_datasets:
# ---> 69                 NYISOData(dataset=dataset, year=self.year, **kwargs)
#      70
#      71     def tables_energy_generation(self, f='D'):
#
# c:\users\tzave\synologydrive\drive\zachary\160-energy\personal_projects\nyisotoolkit\nyisotoolkit\nyisodata\nyisodata.py in __init__(self, dataset, year, redownload, reconstruct, create_csv)
#      91
#      92         self.config()
# ---> 93         self.main()
#      94
#      95     def arg_validation(self):
#
# c:\users\tzave\synologydrive\drive\zachary\160-energy\personal_projects\nyisotoolkit\nyisotoolkit\nyisodata\nyisodata.py in main(self)
#     112                 self.get_raw_data()
#     113             # TODO: DataQuality(dataset=self.dataset, year=self.year).fix_issues()
# --> 114             self.construct_database()
#     115         else:
#     116             self.df = pd.read_pickle(file_)
#
# c:\users\tzave\synologydrive\drive\zachary\160-energy\personal_projects\nyisotoolkit\nyisotoolkit\nyisodata\nyisodata.py in construct_database(self)
#     148             frames = [pd.read_csv(file, index_col=0) for file in files]  # Concatenate all CSVs into a DataFrame
#     149             df = pd.concat(frames, sort=False)
# --> 150             df.index = pd.to_datetime(df.index)
#     151
#     152             if ("Time Zone" in df.columns) or (self.dataset_details.col is None):
#
# ~\.conda\envs\m4rz910env\lib\site-packages\pandas\core\tools\datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#     890         result = _assemble_from_unit_mappings(arg, errors, tz)
#     891     elif isinstance(arg, Index):
# --> 892         cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#     893         if not cache_array.empty:
#     894             result = _convert_and_box_cache(arg, cache_array, name=arg.name)
#
# ~\.conda\envs\m4rz910env\lib\site-packages\pandas\core\tools\datetimes.py in _maybe_cache(arg, format, cache, convert_listlike)
#     193         unique_dates = unique(arg)
#     194         if len(unique_dates) < len(arg):
# --> 195             cache_dates = convert_listlike(unique_dates, format)
#     196             cache_array = Series(cache_dates, index=unique_dates)
#     197             # GH#39882 and GH#35888 in case of None and NaT we get duplicates
#
# ~\.conda\envs\m4rz910env\lib\site-packages\pandas\core\tools\datetimes.py in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     399     assert format is None or infer_datetime_format
#     400     utc = tz == "utc"
# --> 401     result, tz_parsed = objects_to_datetime64ns(
#     402         arg,
#     403         dayfirst=dayfirst,
#
# ~\.conda\envs\m4rz910env\lib\site-packages\pandas\core\arrays\datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object, allow_mixed)
#    2173     order: Literal["F", "C"] = "F" if flags.f_contiguous else "C"
#    2174     try:
# -> 2175         result, tz_parsed = tslib.array_to_datetime(
#    2176             data.ravel("K"),
#    2177             errors=errors,
#
# ~\.conda\envs\m4rz910env\lib\site-packages\pandas\_libs\tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# ~\.conda\envs\m4rz910env\lib\site-packages\pandas\_libs\tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# ~\.conda\envs\m4rz910env\lib\site-packages\pandas\_libs\tslibs\parsing.pyx in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# ~\.conda\envs\m4rz910env\lib\site-packages\dateutil\parser\_parser.py in parse(timestr, parserinfo, **kwargs)
#    1366         return parser(parserinfo).parse(timestr, **kwargs)
#    1367     else:
# -> 1368         return DEFAULTPARSER.parse(timestr, **kwargs)
#    1369
#    1370
#
# ~\.conda\envs\m4rz910env\lib\site-packages\dateutil\parser\_parser.py in parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     638                                                       second=0, microsecond=0)
#     639
# --> 640         res, skipped_tokens = self._parse(timestr, **kwargs)
#     641
#     642         if res is None:
#
# ~\.conda\envs\m4rz910env\lib\site-packages\dateutil\parser\_parser.py in _parse(self, timestr, dayfirst, yearfirst, fuzzy, fuzzy_with_tokens)
#     717
#     718         res = self._result()
# --> 719         l = _timelex.split(timestr)         # Splits the timestr into tokens
#     720
#     721         skipped_idxs = []
#
# ~\.conda\envs\m4rz910env\lib\site-packages\dateutil\parser\_parser.py in split(cls, s)
#     199     @classmethod
#     200     def split(cls, s):
# --> 201         return list(cls(s))
#     202
#     203     @classmethod
#
# ~\.conda\envs\m4rz910env\lib\site-packages\dateutil\parser\_parser.py in __next__(self)
#     188
#     189     def __next__(self):
# --> 190         token = self.get_token()
#     191         if token is None:
#     192             raise StopIteration
#
# ~\.conda\envs\m4rz910env\lib\site-packages\dateutil\parser\_parser.py in get_token(self)
#     115                 # to parse a word, a number or something else.
#     116                 token = nextchar
# --> 117                 if self.isword(nextchar):
#     118                     state = 'a'
#     119                 elif self.isnum(nextchar):
#
# KeyboardInterrupt:
