# %%
import pytest
from datetime import datetime
import pytz
import matplotlib.pyplot as plt

from nyisotoolkit import NYISOVis
from nyisotoolkit.nyisovis.nyisovis import basic_plots, statistical_plots
from nyisotoolkit.nyisodata.utils import current_year

basic_plots({"redownload":False, 'year': 2024})
# Out:
# /home/m4rz177/Documents/NYISOToolkit/nyisotoolkit/nyisovis/nyisovis.py:395: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   cb1.ax.set_yticklabels([i for i in range(0,120,20)])
