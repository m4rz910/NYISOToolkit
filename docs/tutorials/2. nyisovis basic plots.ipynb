# %%
from nyisotoolkit import NYISOVis, NYISOData

# %%
years = [2019]
for year in years:
    nv = NYISOVis(year=year)
    nv.fig_carbon_free_year()
    nv.fig_decarbonization_heatmap()
    nv.fig_decarbonization_clock()
    for f in ['D','M']:
        nv.fig_energy_generation(f=f)
        nv.fig_carbon_free_timeseries(f=f)
print(f"Figures saved by default to: {nv.out_dir} \nYou can change this by passing a pathlib object to the out_dir parameter to the NYISOVis object initialization.")
# Out:
# c:\users\tzave\documents\development\nyisotoolkit\nyisotoolkit\nyisovis\nyisovis.py:418: UserWarning: FixedFormatter should only be used together with FixedLocator
#   cb1.ax.set_yticklabels([i for i in range(0,120,20)])
# Figures saved by default to: C:\Users\tzave\Documents\development\NYISOToolkit\nyisotoolkit\nyisovis\visualizations
# You can change this by passing a pathlib object to the out_dir parameter to the NYISOVis object initialization.
