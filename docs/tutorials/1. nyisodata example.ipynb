# %%
from nyisotoolkit import NYISOData

# %%
df = NYISOData(dataset="load_h", year="2019").df #UTC
df = df.tz_convert("US/Eastern")
df.head(5)
# Out:
# Name                       CAPITL  CENTRL  DUNWOD  GENESE  HUD VL  LONGIL  \
# Time Stamp
# 2019-01-01 00:00:00-05:00  1131.1  1597.6   581.8   897.5   948.6  1974.2
# 2019-01-01 01:00:00-05:00  1082.0  1539.6   560.4   861.0   896.4  1848.9
# 2019-01-01 02:00:00-05:00  1042.0  1490.6   536.3   834.9   848.3  1748.8
# 2019-01-01 03:00:00-05:00  1023.4  1455.8   516.3   807.5   834.5  1675.9
# 2019-01-01 04:00:00-05:00  1021.4  1426.7   501.7   803.0   826.8  1649.2
#
# Name                       MHK VL  MILLWD  N.Y.C.  NORTH    WEST     NYCA
# Time Stamp
# 2019-01-01 00:00:00-05:00   770.7   272.5  4896.0  539.6  1443.2  15052.8
# 2019-01-01 01:00:00-05:00   729.8   260.0  4719.6  529.0  1454.3  14481.0
# 2019-01-01 02:00:00-05:00   701.1   252.5  4532.9  517.9  1421.8  13927.1
# 2019-01-01 03:00:00-05:00   687.2   237.9  4395.6  533.9  1397.6  13565.6
# 2019-01-01 04:00:00-05:00   673.6   234.1  4322.6  529.7  1364.4  13353.2
